# %%
import tensorflow as tf
import matplotlib.pyplot as plot
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-9cef438a93ed> in <module>()
# ----> 1 import tensorflow as tf
#       2 import matplotlib.pyplot as plot
#       3 import numpy as np
#       4
#       5
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/__init__.py in <module>()
#      22
#      23 # pylint: disable=wildcard-import
# ---> 24 from tensorflow.python import *
#      25 # pylint: enable=wildcard-import
#      26
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/__init__.py in <module>()
#      75
#      76 # Bring in subpackages.
# ---> 77 from tensorflow.python.estimator import estimator_lib as estimator
#      78 from tensorflow.python.feature_column import feature_column_lib as feature_column
#      79 from tensorflow.python.layers import layers
#
# ...
